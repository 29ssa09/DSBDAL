# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("facebook.csv");

# %%
df
# Out:
#      pagetotallikes  type  category  postmonth  postweekday  posthour  paid  \
# 0            139441     2         2         12            4         3     0
# 1            139441     3         2         12            3        10     0
# 2            139441     2         3         12            3         3     0
# 3            139441     2         2         12            2        10     1
# 4            139441     2         2         12            2         3     0
# ..              ...   ...       ...        ...          ...       ...   ...
# 367           85093     2         3          1            7        10     0
# 368           85093     2         3          1            7         2     0
# 369           81370     2         2          1            5         8     0
# 370           81370     2         1          1            5         2     0
# 371           81370     2         3          1            4        11     0
#
# ...

# %%
df.describe()
# Out:
#        pagetotallikes        type    category   postmonth  postweekday  \
# count      372.000000  372.000000  372.000000  372.000000   372.000000
# mean    120482.123656    2.040323    1.876344    6.836022     4.212366
# std      17825.647677    0.423040    0.884597    3.756395     2.036211
# min      81370.000000    1.000000    1.000000    1.000000     1.000000
# 25%     107907.000000    2.000000    1.000000    4.000000     2.000000
# 50%     124940.000000    2.000000    2.000000    6.000000     4.000000
# 75%     137059.000000    2.000000    3.000000   11.000000     6.000000
# max     139441.000000    4.000000    3.000000   12.000000     7.000000
#
#          posthour        paid  lifetimeposttotalreach  \
# count  372.000000  372.000000              372.000000
# mean     7.876344    0.255376            13278.422043
# std      4.432273    0.436660            21395.541417
# min      1.000000    0.000000              238.000000
# ...

# %%
df.shape
# Out:
# (372, 19)

# %%
#Creating subsets
df1=df[['pagetotallikes','type','category','postmonth']].loc[0:15];

# %%
df1
# Out:
#     pagetotallikes  type  category  postmonth
# 0           139441     2         2         12
# 1           139441     3         2         12
# 2           139441     2         3         12
# 3           139441     2         2         12
# 4           139441     2         2         12
# 5           139441     3         2         12
# 6           139441     2         3         12
# 7           139441     2         3         12
# 8           139441     3         2         12
# 9           139441     2         3         12
# 10          139441     3         2         12
# 11          139441     2         2         12
# 12          139441     2         2         12
# 13          139441     2         2         12
# 14          138414     2         2         12
# 15          138414     3         2         12

# %%
df2=df[['pagetotallikes','type','category','postmonth']].loc[15:30];
df2
# Out:
#     pagetotallikes  type  category  postmonth
# 15          138414     3         2         12
# 16          138414     2         3         12
# 17          138414     2         1         12
# 18          138414     3         3         12
# 19          138414     2         3         12
# 20          138414     2         2         12
# 21          138414     2         1         12
# 22          138414     1         1         12
# 23          138414     2         3         12
# 24          138414     3         2         12
# 25          138458     3         2         12
# 26          138458     3         2         12
# 27          138458     2         3         12
# 28          138895     2         2         12
# 29          138895     4         1         12
# 30          138895     2         2         12

# %%
df3=df[['pagetotallikes','type','category','postmonth']].loc[30:40];
df3
# Out:
#     pagetotallikes  type  category  postmonth
# 30          138895     2         2         12
# 31          138895     2         2         12
# 32          138895     2         3         12
# 33          138895     2         3         12
# 34          138895     2         1         12
# 35          138895     2         2         12
# 36          138895     2         3         12
# 37          138895     2         1         12
# 38          138895     3         2         12
# 39          138895     2         1         12
# 40          138895     3         2         12

# %%
#Merge Data
merge_data=pd.concat([df1,df2,df3]);
merge_data
# Out:
#     pagetotallikes  type  category  postmonth
# 0           139441     2         2         12
# 1           139441     3         2         12
# 2           139441     2         3         12
# 3           139441     2         2         12
# 4           139441     2         2         12
# 5           139441     3         2         12
# 6           139441     2         3         12
# 7           139441     2         3         12
# 8           139441     3         2         12
# 9           139441     2         3         12
# 10          139441     3         2         12
# 11          139441     2         2         12
# 12          139441     2         2         12
# 13          139441     2         2         12
# 14          138414     2         2         12
# 15          138414     3         2         12
# 15          138414     3         2         12
# 16          138414     2         3         12
# 17          138414     2         1         12
# ...

# %%
#sortdata
sorting=df.sort_values('category',ascending=True);
sorting
# Out:
#      pagetotallikes  type  category  postmonth  postweekday  posthour  paid  \
# 345           91223     2         1          2            2        13     0
# 110          136736     2         1         10            6        10     0
# 302          100732     2         1          3            7        15     0
# 334           92400     2         1          2            1         4     0
# 113          136642     2         1         10            7        13     0
# ..              ...   ...       ...        ...          ...       ...   ...
# 220          117764     2         3          5            6        13     0
# 221          117764     2         3          5            6         8     1
# 222          117764     2         3          5            5        13     0
# 210          119198     2         3          5            6         6     0
# 371           81370     2         3          1            4        11     0
#
# ...

# %%
#Transpose the data
transpose=df.transpose();

# %%
transpose
# Out:
#                                                        0       1       2    \
# pagetotallikes                                      139441  139441  139441
# type                                                     2       3       2
# category                                                 2       2       3
# postmonth                                               12      12      12
# postweekday                                              4       3       3
# posthour                                                 3      10       3
# paid                                                     0       0       0
# lifetimeposttotalreach                                2752   10460    2413
# lifetimeposttotalimpressions                          5091   19057    4373
# lifetimeengagedusers                                   178    1457     177
# lifetimepostconsumers                                  109    1361     113
# ...

# %%
#shape and reshape of data
#shape
df.shape
# Out:
# (372, 19)

# %%
#reshape
pivot_table=pd.pivot_table(df,index=['type' , 'category'], values='comment')
pivot_table
# Out:
#                 comment
# type category
# 1    1         2.900000
#      2         2.000000
#      3         2.000000
# 2    1         5.298611
#      2         8.773585
#      3         7.075000
# 3    1         4.333333
#      2         7.454545
#      3         2.750000
# 4    1         9.750000
